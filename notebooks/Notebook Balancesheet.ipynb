# %%
# import fibooks libraries
from fibooks import balance_sheet
from fibooks import income_statement
from fibooks import statement_of_cashflows
from fibooks import other
# other libraries (that are integrated with fibooks)
import pandas as pd
import seaborn as sns
from sklearn import tree
import matplotlib.pyplot as plt

# %%
company_c = balance_sheet('company c')
company_c.load_excel('bs.xlsx')
company_c.content
# Out:
#       cash  petty cash  accounts receivables  inventory  prepaid expenses  \
# 0  21506.0       200.0                5013.0    20887.0            1098.0
# 1  20000.0       200.0                5000.0    21000.0            1100.0
# 2   1506.0         0.0                  13.0     -113.0              -2.0
#
#    employee advances  temporary investments      land  buildings  \
# 0              100.0                    0.0  150000.0    60235.0
# 1                0.0                    0.0  150000.0    60235.0
# 2              100.0                    0.0       0.0        0.0
#
#    furniture and equipment  ...  notes payable  mortgage payable  \
# 0                  28777.0  ...        50195.0          148222.0
# 1                  30777.0  ...        48301.0          146231.0
# 2                  -2000.0  ...         1894.0            1991.0
#
#    less: current portion of long-term debt  capital stock/partner's equity  \
# 0                                  -1200.0                         20000.0
# 1                                  -1200.0                         20000.0
# 2                                      0.0                             0.0
#
#    opening retained earnings  dividends paid/owner's draw  net income (loss)  \
# 0                    25530.0                      -5000.0             8599.0
# 1                    29129.0                      -5000.0             9018.0
# 2                    -3599.0                          0.0             -419.0
#
#    total equity  total liabilities & equity  balance sheet check
# 0       49129.0                    288595.0                  0.0
# 1       53147.0                    287090.0                  0.0
# 2       -4018.0                      1505.0                  NaN
#
# [3 rows x 36 columns]
